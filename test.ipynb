# %%
# %pip install -U -q google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\03123\appdata\local\programs\python\python311\lib\site-packages\mcqgenerator-0.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\03123\appdata\local\programs\python\python311\lib\site-packages\pypdf2-3.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
from google import genai
from google.genai import types
import requests
from PIL import Image
from io import BytesIO

# %%
# image_path = "https://goo.gle/instrument-img"
image_path = "https://www.thesunnysideupblog.com/wp-content/uploads/2022/07/fridge-sunnyside-up-8.jpg"

image = requests.get(image_path)

# %%
image_open = Image.open(BytesIO(image.content))
image_open
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1200>

# %%
client = genai.Client(api_key="AIzaSyBbOGCc7bdUahCvMVmB51CESOHSo0FB5S0")
response = client.models.generate_content(
    model="gemini-2.0-flash-exp",
    contents=["What are the contents of this fridge? Please tell me what is in each shelf",
              types.Part.from_bytes(data=image.content, mime_type="image/jpeg")])

print(response.text)
# Out:
# Okay, here's a breakdown of the fridge contents by shelf, going from top to bottom:
#
# **Top Shelf:**
#
# *   Green beans
# *   Strawberries
# *   Celery
# *   Cans of Coca-Cola
#
# **Second Shelf:**
#
# *   Packages of sliced swiss cheese
# *   Packages of purple yogurt
# *   Stack of containers
# *   Feta cheese
# *   Eggs
#
# **Third Shelf:**
#
# *   Grapes
# *   Sugar snap peas
# *   Carrot sticks
# *   Lunchables
# *   Cherries
# *   Lemons
#
# **Fourth Shelf:**
#
# *   Bell peppers (green and orange)
# *   A clear container with salad greens
# *   A gallon of milk
#
# **Bottom drawer shelf:**
#
# *   Cheese
# *   Microwave Ready food
#
# **Bottom shelf drawer:**
#
# *   Lettuce
# *   Grilled Chicken Strips
#
# **Door Shelves:**
#
# *   Sauces and condiments (mustard, ketchup)
# *   Salad toppings (pecans, croutons)
# *   Cheese (country crock)
